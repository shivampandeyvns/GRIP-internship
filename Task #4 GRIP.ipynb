# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data=pd.read_csv('terrorismData.csv',low_memory=False)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.isnull().sum()
# Out:
# eventid     0
# iyear       0
# imonth      0
# iday        0
# extended    0
#            ..
# dbsource    0
# INT_LOG     0
# INT_IDEO    0
# INT_MISC    0
# INT_ANY     0
# Length: 133, dtype: int64

# %%
data.drop(['approxdate','related','resolution'],axis=1,inplace=True)

# %%
data.drop('resolution',axis=1,inplace=True)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  1.970000e+11   1970       7     2         0       58  Dominican Republic
# 1  1.970000e+11   1970       0     0         0      130              Mexico
# 2  1.970010e+11   1970       1     0         0      160         Philippines
# 3  1.970010e+11   1970       1     0         0       78              Greece
# 4  1.970010e+11   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate  ... nreleased  addnotes  \
# 0       2  Central America & Caribbean       NaN  ...       NaN       NaN
# 1       1                North America   Federal  ...       NaN       NaN
# 2       5               Southeast Asia    Tarlac  ...       NaN       NaN
# 3       8               Western Europe    Attica  ...       NaN       NaN
# 4       4                    East Asia   Fukouka  ...       NaN       NaN
#
# ...

# %%
geo_data=data[['latitude','longitude']]

# %%
geo_data.head()
# Out:
#     latitude   longitude
# 0  18.456792  -69.951164
# 1  19.371887  -99.086624
# 2  15.478598  120.599741
# 3  37.997490   23.762728
# 4  33.580412  130.396361

# %%
geo_data.dropna(inplace=True)
# Out:
# <ipython-input-67-ae5cadb576b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geo_data.dropna(inplace=True)

# %%
data['latitude'].dropna(inplace=True)
data['longitude'].dropna(inplace=True)

# %%
import folium
from folium import plugins

# %%
map=folium.Map(location=[0,0],zoom_start=0)
marker_cluster=plugins.MarkerCluster().add_to(map)

# %%
for lat,long in zip(X_test,y_test):

    folium.CircleMarker(location=[lat,long],
                        radius=3,
                        popup=folium.Popup(),
                        color='#FFBA00',
                        fill_color='#FFBA00', 
                        ).add_to(marker_cluster)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(geo_data['latitude'],geo_data['longitude'],test_size=0.01,shuffle=True)
